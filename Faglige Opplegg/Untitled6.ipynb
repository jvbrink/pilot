# %%
from pylab import *
gray()

# %%
img = imread("fig/flowers.jpg")

imshow(img)
show()

# %%
rød = img[:, :, 0]
grønn = img[:, :, 1]
blå = img[:, : 2]

rødgrønn = rød/2 + grønn/2

fargeblind = img.copy()
fargeblind[:, :, 0] = rødgrønn
fargeblind[:, :, 1] = rødgrønn

imshow(fargeblind)
show()
