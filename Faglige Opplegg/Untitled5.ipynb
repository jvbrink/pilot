# %%
from pylab import *
gray()

# %%
from skimage import data

# %%
img = data.camera()

imshow(img)
show()

# %%
print(img)
# Out:
# [[156 157 160 ... 152 152 152]
#  [156 157 159 ... 152 152 152]
#  [158 157 156 ... 152 152 152]
#  ...
#  [121 123 126 ... 121 113 111]
#  [121 123 126 ... 121 113 111]
#  [121 123 126 ... 121 113 111]]

# %%
print(img.shape)
# Out:
# (512, 512)

# %%
print(512*512)
# Out:
# 262144

# %%
print(img.min())
print(img.max())
# Out:
# 0
# 255

# %%
imshow(img)
colorbar()
show()

# %%
print(img.dtype)
# Out:
# uint8

# %% [markdown]
# $$2\times 2\times \times 2 \ldots \times 2 = 2^8 = 256$$

# %%
antall_piksler = (512*512)
antall_bit = antall_piksler * 8
antall_byte = antall_bit/8
antall_megabyte = antall_byte/1e6

print(antall_megabyte)
# Out:
# 0.262144

# %% [markdown]
# # RGB-farger
#
# Rød-Grønn-Blå

# %%
from skimage import data

img = data.chelsea()

imshow(img)
show()

# %%
print(img.shape)
# Out:
# (427, 640, 3)

# %%
print(img.dtype)
# Out:
# uint8

# %%
img[0, 0]
# Out:
# array([17, 33, 58], dtype=uint8)

# %%
rød = img[:, :, 0]
grønn = img[:, :, 1]
blå = img[:, :, 2]

# %%
imshow(rød)
title('Rød')
show()

# %%
imshow(grønn)
title('grønn')
show()

# %%
imshow(blå)
title('blå')
show()

# %%
img = imread("fig/peppers.png")

imshow(img)
show()

# %%
rød = img[:, :, 0]
grønn = img[:, :, 1]
blå = img[:, :, 2]

print(img.shape)
print(rød.shape)
# Out:
# (384, 512, 4)
# (384, 512)
